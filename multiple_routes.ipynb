# %%
import itertools

import folium
import folium.plugins
import numpy as np
import pandas as pd
import polyline
import requests
import map_route as mp
from folium import Marker

# %%
data_points_r1 = [
    ["UNAL", 6.2623506, -75.5778091],
    ["UPB", 6.2536481, -75.5815857],
    ["IUE", 6.1621011, -75.5944852],
]
points_r1 = pd.DataFrame(data_points_r1, columns=["id", "Latitud", "Longitud"])

data_points_r2 = [
    ["Santo Domingo", 6.297463, -75.5505485],
    ["Parque Aranjuez", 6.2803677, -75.559826],
    ["Hospital Infantil Concejo de Medellín", 6.268107, -75.558886],
    ["La Pascascia", 6.243173, -75.563598]
]
points_r2 = pd.DataFrame(data_points_r2, columns=["id", "Latitud", "Longitud"])

# %%
info_route_1 = mp.get_route(points_r1)
info_route_2 = mp.get_route(points_r2)

# %%
multiple_infos = [info_route_1, info_route_2]
colors = [ 'darkblue', "black", "green", "darpurple",  'cadetblue', 'darkblue', 'darkgreen', 'darkpurple', 'darkred', 'gray', 'green', 'lightblue', 'lightgray', 'lightgreen', 'lightred', 'orange', 'pink', 'purple', 'red', 'white']
mp.mult_routes(multiple_infos, colors, animated = True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
